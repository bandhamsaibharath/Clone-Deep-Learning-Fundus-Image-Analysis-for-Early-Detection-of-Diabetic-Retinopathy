# %%
train_path = r"C:\Users\bandh\Documents\Diabetic_Retinopathy_Project\dataset\preprocessed dataset\training"
test_path  = r"C:\Users\bandh\Documents\Diabetic_Retinopathy_Project\dataset\preprocessed dataset\testing"
